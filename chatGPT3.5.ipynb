# %%
import openai
import json
# openai.api_key ="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"
openai.api_key ="sk-H9kHXOCBqAYfeFLGA44666E7F80445EcAbD1F626F9BcD70e"
openai.api_base = "https://gtapi.xiaoerchaoren.com:8932/v1";
# openai.api_key ="sk-H9kHXOCBqAYfeFLGA44666E7F80445EcAbD1F626F9BcD70e"
completion = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
        {"role": "system", "content": "作为一个社交媒体用户，用中文为以下帖子生成一条让人共情的回复(请用中文回复)"},
        {"role": "user", "content": "试用期不买五险一金hr居然说.... hr说试用期不买五险一金，我说不买五险一金违法,hr说不买是违规不违法哦，没有上升到法律层面。yue了"}
    ]
)
print(completion)
print(completion.choices[0].message['content'])
# for i in completion:
#   print(i)

# %%
import openai
import json
import pickle as pkl
import time
openai.api_key = "sk-oUHVjesXusuAEckUA0A53eB3B57e4a07Be6297959547F275"
openai.api_base = "https://gtapi.xiaoerchaoren.com:8932/v1";
responses = []
import pandas as pd
file = pd.read_csv("zctytlxz_postid_pre_final.csv")
for i in range(100):
    j = i + 5600
    completion = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "作为一个社交媒体用户，在讨论职场问题的小组里看到以下帖子，用中文为它生成一条让人共情的回复"},
            {"role": "user", "content": file['postkey'][j][:6500]}
        ]
    )
    st = completion.choices[0].message['content']
    responses.append(st)
    print(j)
#     if i%100 == 0 and i != 0:
#         with open(f"result_zctytlxz_{j}_rt.pkl".format(), "wb") as fa:
#             pkl.dump(responses, fa)
  # print(responses)
with open("result_zctytlxz_5600.pkl", "wb") as f:
    pkl.dump(responses, f)
# print(responses)
print(len(responses))
# print(completion.choices[0].message['content'])
# Out:
# 5600
# 5601
# 5602
# 5603
# 5604
# 5605
# 5606
# 5607
# 5608
# 5609
# 5610
# 5611
# 5612
# 5613
# 5614
# 5615
# 5616
# 5617
# 5618
# 5619
# 5620
# 5621
# 5622
# 5623
# 5624
# 5625
# 5626
# 5627
# 5628
# 5629
# 5630
# 5631
# 5632
# 5633
# 5634
# 5635
# 5636
# 5637
# 5638
# 5639
# 5640
# 5641
# 5642
# 5643
# 5644
# 5645
# 5646
# 5647
# 5648
# 5649
# 5650
# 5651
# 5652
# 5653
# 5654
# 5655
# 5656
# 5657
# 5658
# 5659
# 5660
# 5661
# 5662
# 5663
# 5664
# 5665
# 5666
# 5667
# 5668
# 5669
# 5670
# 5671
# 5672
# 5673
# 5674
# 5675
# 5676
# 5677
# 5678
# 5679
# 5680
# 5681
# 5682
# 5683
# 5684
# 5685
# 5686
# 5687
# 5688
# 5689
# 5690
# 5691
# 5692
# 5693
# 5694
# 5695
# 5696
# 5697
# 5698
# 5699
# 100

# %%
data = []
with open("result_zctytlxz_8000.txt","r")as f:
    for i in f.readlines():
        data.append(i)
print(len(data))
# Out:
# 0

# %%
i = 100000
with open(f"result_zctytlxz_{i}.pkl".format(), "wb") as f:
  pkl.dump(responses, f)
